# %% [markdown]
# # Sort CSV File
#
# - do the sorting according to the id

# %%
import pandas as pd

def sort_csv_by_column(csv_path, column_name, ascending=True):
    """
    Sort a CSV file by a specified column and save it back to the same file.
    
    Parameters:
    - csv_path: str, path to the CSV file
    - column_name: str, name of the column to sort by
    - ascending: bool, sort order (default: True for ascending)
    
    Returns:
    - DataFrame: The sorted dataframe
    """
    # Read the CSV file
    df = pd.read_csv(csv_path)
    
    # Check if column exists
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in CSV. Available columns: {list(df.columns)}")
    
    # Sort by the specified column
    df_sorted = df.sort_values(by=column_name, ascending=ascending)
    
    # Save back to the same file
    df_sorted.to_csv(csv_path, index=False)
    
    print(f"CSV file sorted by '{column_name}' ({'ascending' if ascending else 'descending'}) and saved to {csv_path}")
    print(f"Total rows: {len(df_sorted)}")
    
    return df_sorted

# %%
# Example usage:
csv_file_path = '/Users/adityakumar/Developer/Projects/mini_project/features/labels.csv'
sort_csv_by_column(csv_file_path, 'ID')
# sort_csv_by_column('/path/to/file.csv', 'duration', ascending=False)
# Out:
# CSV file sorted by 'ID' (ascending) and saved to /Users/adityakumar/Developer/Projects/mini_project/features/labels.csv
# Total rows: 872
#                 ID  duration  \
# 330  S03_03a02Fc_1      1.00
# 274  S03_03a02Fc_2      1.00
# 823  S03_03a02Wb_1      1.06
# 759  S03_03a02Wb_2      1.06
# 617  S03_03a04Ta_1      1.03
# ..             ...       ...
# 486  S16_16b10Td_2      1.97
# 247  S16_16b10Wa_1      1.21
# 304  S16_16b10Wa_2      1.21
# 43   S16_16b10Wb_1      1.26
# 99   S16_16b10Wb_2      1.26
#
#                                                    wav  start   stop spk_id  \
# 330  /Users/adityakumar/Developer/Projects/mini_pro...      0  16000    S03
# 274  /Users/adityakumar/Developer/Projects/mini_pro...      0  16000    S03
# 823  /Users/adityakumar/Developer/Projects/mini_pro...      0  16960    S03
# 759  /Users/adityakumar/Developer/Projects/mini_pro...      0  16960    S03
# 617  /Users/adityakumar/Developer/Projects/mini_pro...      0  16480    S03
# ..                                                 ...    ...    ...    ...
# 486  /Users/adityakumar/Developer/Projects/mini_pro...      0  31520    S16
# 247  /Users/adityakumar/Developer/Projects/mini_pro...      0  19360    S16
# 304  /Users/adityakumar/Developer/Projects/mini_pro...      0  19360    S16
# 43   /Users/adityakumar/Developer/Projects/mini_pro...      0  20160    S16
# 99   /Users/adityakumar/Developer/Projects/mini_pro...      0  20160    S16
#
#      label
# 330      0
# 274      0
# 823      2
# 759      2
# 617      6
# ..     ...
# 486      6
# 247      2
# 304      2
# 43       2
# 99       2
#
# [872 rows x 7 columns]
