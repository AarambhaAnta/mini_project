# %%
# Install required libraries
# !pip install librosa numpy pandas scikit-learn tensorflow matplotlib

# %% [markdown]
# # Audio split

# %% [markdown]
# ## Imports

# %%
import wave
import os
import csv
import glob

# %% [markdown]
# ## Function for splitting into parts

# %%
def split_wav(path, parts, output_location=None):
    """
    Split a .wav file into equal duration parts.
    
    Parameters:
    - path: str, path to the .wav file
    - parts: int, number of parts to split into
    - output_location: str, directory to save split files (default: same as input file)
    
    Returns:
    - List of paths to the split files
    """
    # Open the audio file
    
    with wave.open(path, 'rb') as audio:
        # Get audio parameters
        params = audio.getparams()
        n_channels = params.nchannels
        sampwidth = params.sampwidth
        framerate = params.framerate
        n_frames = params.nframes
        
        # Read all frames
        frames = audio.readframes(n_frames)
    
    # Calculate frames per part
    frames_per_part = n_frames // parts
    
    # Get base name and directory
    base_name = os.path.splitext(os.path.basename(path))[0]
    
    # Extract speaker ID (first 2 characters of filename)
    speaker_id = base_name[0:2]
    
    # Use output_location if provided, otherwise use input file directory
    if output_location:
        directory = output_location
        # Create output directory if it doesn't exist
        os.makedirs(directory, exist_ok=True)
    else:
        directory = os.path.dirname(path) or '.'
    
    # Split and save parts
    output_paths = []
    for i in range(parts):
        # Calculate start and end frames
        start_frame = i * frames_per_part
        
        # For the last part, include any remaining frames
        if i == parts - 1:
            end_frame = n_frames
        else:
            end_frame = (i + 1) * frames_per_part
        
        # Calculate byte positions (each frame has sampwidth bytes per channel)
        bytes_per_frame = n_channels * sampwidth
        start_byte = start_frame * bytes_per_frame
        end_byte = end_frame * bytes_per_frame
        
        # Extract the part
        part_frames = frames[start_byte:end_byte]
        
        # Create output path with speaker ID prefix
        output_path = os.path.join(directory, f"S{speaker_id}_{base_name}_{i+1}.wav")
        
        # Write the part to a new file
        with wave.open(output_path, 'wb') as part_audio:
            part_audio.setparams(params)
            part_audio.writeframes(part_frames)
        
        duration = (end_frame - start_frame) / framerate
        output_paths.append(output_path)
        print(f"Created: {output_path} (duration: {duration:.2f}s)")
    
    return output_paths

# %%
# audio_path = "/Users/adityakumar/Developer/Projects/mini_project/dataset/03a05Tc.wav"
# output_path = "/Users/adityakumar/Developer/Projects/mini_project/output"
# print(split_wav(audio_path, 3, output_path))

# %% [markdown]
# ## Function to create CSV of output file duration

# %%
def create_audio_duration_csv(folder_location, csv_folder_location):
    """
    Create a CSV file with filename and duration for all .wav files in a folder.
    
    Parameters:
    - folder_location: str, path to folder containing .wav files
    - csv_folder_location: str, path to folder where CSV will be saved
    
    Returns:
    - Path to the created CSV file
    """
    # Get all .wav files in the folder
    wav_files = glob.glob(os.path.join(folder_location, "*.wav"))
    
    # Create csv folder if it doesn't exist
    os.makedirs(csv_folder_location, exist_ok=True)
    
    # Create CSV file path
    csv_path = os.path.join(csv_folder_location, "audio_durations.csv")
    
    # Collect file data
    file_data = []
    for wav_file in wav_files:
        # Get duration using wave module
        with wave.open(wav_file, 'rb') as audio:
            frames = audio.getnframes()
            rate = audio.getframerate()
            duration = frames / float(rate)
        
        filename = os.path.basename(wav_file)
        file_data.append({'filename': filename, 'duration(sec)': round(duration, 2)})
    
    # Write to CSV
    with open(csv_path, 'w', newline='') as csvfile:
        fieldnames = ['filename', 'duration(sec)']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        writer.writeheader()
        writer.writerows(file_data)
    
    print(f"CSV created at: {csv_path} with {len(file_data)} files")
    return csv_path

# %% [markdown]
# ## Splitting the data into parts

# %%
# Split all .wav files in the dataset folder
dataset_folder = "/Users/adityakumar/Developer/Projects/mini_project/dataset"
output_folder = "/Users/adityakumar/Developer/Projects/mini_project/output"

# Get all .wav files
wav_files = os.listdir(dataset_folder)

print(f"Found {len(wav_files)} .wav files to split")

# Split each file based on duration
for wav_file in wav_files:
    # Get duration
    wav_file_path = os.path.join(dataset_folder, wav_file)
    with wave.open(wav_file_path, 'rb') as audio:
        frames = audio.getnframes()
        rate = audio.getframerate()
        duration = frames / float(rate)
    
    
    if duration >= 6:
        parts = 4
    elif duration >= 4:
        parts = 3
    elif duration >= 2:
        parts = 2
    else:
        parts = 1
    
    # Final safety check
    part_duration = duration / parts
    print(f"\nProcessing: {os.path.basename(wav_file)} (duration: {duration:.2f}s, parts: {parts}, part_duration: {part_duration:.2f}s)")
    
    if parts > 1:
        split_wav(wav_file_path, parts, output_folder)
    else:
        print("  Skipping (duration < 2 seconds)")
# Out:
# Found 535 .wav files to split
#
# Processing: 16a02Lb.wav (duration: 2.08s, parts: 2, part_duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a02Lb_1.wav (duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a02Lb_2.wav (duration: 1.04s)
#
# Processing: 14a07Wc.wav (duration: 2.06s, parts: 2, part_duration: 1.03s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Wc_1.wav (duration: 1.03s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Wc_2.wav (duration: 1.03s)
#
# Processing: 10a07Ad.wav (duration: 1.60s, parts: 1, part_duration: 1.60s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13a05Ea.wav (duration: 4.20s, parts: 3, part_duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a05Ea_1.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a05Ea_2.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a05Ea_3.wav (duration: 1.40s)
#
# Processing: 14a05Wa.wav (duration: 4.01s, parts: 3, part_duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Wa_1.wav (duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Wa_2.wav (duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Wa_3.wav (duration: 1.34s)
#
# Processing: 14a07Na.wav (duration: 2.10s, parts: 2, part_duration: 1.05s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Na_1.wav (duration: 1.05s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Na_2.wav (duration: 1.05s)
#
# Processing: 15a05Wa.wav (duration: 3.10s, parts: 2, part_duration: 1.55s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15a05Wa_1.wav (duration: 1.55s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15a05Wa_2.wav (duration: 1.55s)
#
# Processing: 16b10Wb.wav (duration: 2.52s, parts: 2, part_duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b10Wb_1.wav (duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b10Wb_2.wav (duration: 1.26s)
#
# Processing: 09a01Nb.wav (duration: 1.68s, parts: 1, part_duration: 1.68s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16a01Fc.wav (duration: 2.10s, parts: 2, part_duration: 1.05s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a01Fc_1.wav (duration: 1.05s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a01Fc_2.wav (duration: 1.05s)
#
# Processing: 14a04Ed.wav (duration: 2.92s, parts: 2, part_duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a04Ed_1.wav (duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a04Ed_2.wav (duration: 1.46s)
#
# Processing: 11a01Ab.wav (duration: 1.50s, parts: 1, part_duration: 1.50s)
#   Skipping (duration < 2 seconds)
#
# Processing: 09b02Na.wav (duration: 2.70s, parts: 2, part_duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b02Na_1.wav (duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b02Na_2.wav (duration: 1.35s)
#
# Processing: 03a05Nd.wav (duration: 3.17s, parts: 2, part_duration: 1.58s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a05Nd_1.wav (duration: 1.58s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a05Nd_2.wav (duration: 1.58s)
#
# Processing: 10a01Ac.wav (duration: 1.68s, parts: 1, part_duration: 1.68s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16a04Ab.wav (duration: 1.48s, parts: 1, part_duration: 1.48s)
#   Skipping (duration < 2 seconds)
#
# Processing: 15b02Nd.wav (duration: 2.79s, parts: 2, part_duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b02Nd_1.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b02Nd_2.wav (duration: 1.40s)
#
# Processing: 16b09Wb.wav (duration: 3.69s, parts: 2, part_duration: 1.84s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b09Wb_1.wav (duration: 1.84s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b09Wb_2.wav (duration: 1.84s)
#
# Processing: 11a01Ld.wav (duration: 2.08s, parts: 2, part_duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a01Ld_1.wav (duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a01Ld_2.wav (duration: 1.04s)
#
# Processing: 08a01Wa.wav (duration: 1.61s, parts: 1, part_duration: 1.61s)
#   Skipping (duration < 2 seconds)
#
# Processing: 09b02Wc.wav (duration: 2.72s, parts: 2, part_duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b02Wc_1.wav (duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b02Wc_2.wav (duration: 1.36s)
#
# Processing: 12b09Td.wav (duration: 5.41s, parts: 3, part_duration: 1.80s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b09Td_1.wav (duration: 1.80s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b09Td_2.wav (duration: 1.80s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b09Td_3.wav (duration: 1.80s)
#
# Processing: 10b02Aa.wav (duration: 2.46s, parts: 2, part_duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b02Aa_1.wav (duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b02Aa_2.wav (duration: 1.23s)
#
# Processing: 16a04Tc.wav (duration: 3.17s, parts: 2, part_duration: 1.58s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a04Tc_1.wav (duration: 1.58s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a04Tc_2.wav (duration: 1.58s)
#
# Processing: 16b01La.wav (duration: 2.94s, parts: 2, part_duration: 1.47s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01La_1.wav (duration: 1.47s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01La_2.wav (duration: 1.47s)
#
# Processing: 13b01Wa.wav (duration: 2.25s, parts: 2, part_duration: 1.13s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b01Wa_1.wav (duration: 1.13s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b01Wa_2.wav (duration: 1.13s)
#
# Processing: 12b01Wa.wav (duration: 2.24s, parts: 2, part_duration: 1.12s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b01Wa_1.wav (duration: 1.12s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b01Wa_2.wav (duration: 1.12s)
#
# Processing: 13b03Na.wav (duration: 3.57s, parts: 2, part_duration: 1.78s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Na_1.wav (duration: 1.78s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Na_2.wav (duration: 1.78s)
#
# Processing: 12a02Wc.wav (duration: 1.47s, parts: 1, part_duration: 1.47s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16b03Ad.wav (duration: 3.22s, parts: 2, part_duration: 1.61s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03Ad_1.wav (duration: 1.61s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03Ad_2.wav (duration: 1.61s)
#
# Processing: 13b03Wc.wav (duration: 3.61s, parts: 2, part_duration: 1.81s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Wc_1.wav (duration: 1.81s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Wc_2.wav (duration: 1.81s)
#
# Processing: 13b01Nc.wav (duration: 2.43s, parts: 2, part_duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b01Nc_1.wav (duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b01Nc_2.wav (duration: 1.22s)
#
# Processing: 15a02Ea.wav (duration: 2.45s, parts: 2, part_duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15a02Ea_1.wav (duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15a02Ea_2.wav (duration: 1.22s)
#
# Processing: 11a05Td.wav (duration: 5.67s, parts: 3, part_duration: 1.89s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Td_1.wav (duration: 1.89s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Td_2.wav (duration: 1.89s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Td_3.wav (duration: 1.89s)
#
# Processing: 14a02Ea.wav (duration: 2.55s, parts: 2, part_duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a02Ea_1.wav (duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a02Ea_2.wav (duration: 1.28s)
#
# Processing: 09b03Ed.wav (duration: 5.07s, parts: 3, part_duration: 1.69s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Ed_1.wav (duration: 1.69s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Ed_2.wav (duration: 1.69s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Ed_3.wav (duration: 1.69s)
#
# Processing: 13a02Wa.wav (duration: 1.67s, parts: 1, part_duration: 1.67s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16b03La.wav (duration: 4.04s, parts: 3, part_duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03La_1.wav (duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03La_2.wav (duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03La_3.wav (duration: 1.35s)
#
# Processing: 12a02Wa.wav (duration: 1.51s, parts: 1, part_duration: 1.51s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13b10La.wav (duration: 2.35s, parts: 2, part_duration: 1.17s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b10La_1.wav (duration: 1.17s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b10La_2.wav (duration: 1.17s)
#
# Processing: 03b02Wb.wav (duration: 3.18s, parts: 2, part_duration: 1.59s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Wb_1.wav (duration: 1.59s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Wb_2.wav (duration: 1.59s)
#
# Processing: 13a02Nc.wav (duration: 1.56s, parts: 1, part_duration: 1.56s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16b01Lc.wav (duration: 2.47s, parts: 2, part_duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Lc_1.wav (duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Lc_2.wav (duration: 1.23s)
#
# Processing: 16b10Wa.wav (duration: 2.41s, parts: 2, part_duration: 1.21s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b10Wa_1.wav (duration: 1.21s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b10Wa_2.wav (duration: 1.21s)
#
# Processing: 15b01Ec.wav (duration: 2.97s, parts: 2, part_duration: 1.49s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b01Ec_1.wav (duration: 1.49s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b01Ec_2.wav (duration: 1.49s)
#
# Processing: 14a05Wb.wav (duration: 3.05s, parts: 2, part_duration: 1.53s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Wb_1.wav (duration: 1.53s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Wb_2.wav (duration: 1.53s)
#
# Processing: 14b02Wd.wav (duration: 2.29s, parts: 2, part_duration: 1.15s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b02Wd_1.wav (duration: 1.15s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b02Wd_2.wav (duration: 1.15s)
#
# Processing: 08a01Na.wav (duration: 1.76s, parts: 1, part_duration: 1.76s)
#   Skipping (duration < 2 seconds)
#
# Processing: 08a01Wc.wav (duration: 1.69s, parts: 1, part_duration: 1.69s)
#   Skipping (duration < 2 seconds)
#
# Processing: 11a01Aa.wav (duration: 1.56s, parts: 1, part_duration: 1.56s)
#   Skipping (duration < 2 seconds)
#
# Processing: 08b02Nb.wav (duration: 3.06s, parts: 2, part_duration: 1.53s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b02Nb_1.wav (duration: 1.53s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b02Nb_2.wav (duration: 1.53s)
#
# Processing: 13b09La.wav (duration: 2.59s, parts: 2, part_duration: 1.30s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b09La_1.wav (duration: 1.30s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b09La_2.wav (duration: 1.30s)
#
# Processing: 09a01Wb.wav (duration: 1.70s, parts: 1, part_duration: 1.70s)
#   Skipping (duration < 2 seconds)
#
# Processing: 11b02Ab.wav (duration: 2.49s, parts: 2, part_duration: 1.24s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Ab_1.wav (duration: 1.24s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Ab_2.wav (duration: 1.24s)
#
# Processing: 15a07Nc.wav (duration: 1.88s, parts: 1, part_duration: 1.88s)
#   Skipping (duration < 2 seconds)
#
# Processing: 14b01Eb.wav (duration: 3.29s, parts: 2, part_duration: 1.65s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b01Eb_1.wav (duration: 1.65s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b01Eb_2.wav (duration: 1.65s)
#
# Processing: 11a05Ad.wav (duration: 2.92s, parts: 2, part_duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Ad_1.wav (duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Ad_2.wav (duration: 1.46s)
#
# Processing: 03a01Nc.wav (duration: 1.61s, parts: 1, part_duration: 1.61s)
#   Skipping (duration < 2 seconds)
#
# Processing: 12a02Nb.wav (duration: 1.73s, parts: 1, part_duration: 1.73s)
#   Skipping (duration < 2 seconds)
#
# Processing: 11a05Lc.wav (duration: 4.07s, parts: 3, part_duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Lc_1.wav (duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Lc_2.wav (duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Lc_3.wav (duration: 1.36s)
#
# Processing: 15a05Na.wav (duration: 3.12s, parts: 2, part_duration: 1.56s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15a05Na_1.wav (duration: 1.56s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15a05Na_2.wav (duration: 1.56s)
#
# Processing: 03a01Wa.wav (duration: 1.88s, parts: 1, part_duration: 1.88s)
#   Skipping (duration < 2 seconds)
#
# Processing: 14a05Na.wav (duration: 3.06s, parts: 2, part_duration: 1.53s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Na_1.wav (duration: 1.53s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Na_2.wav (duration: 1.53s)
#
# Processing: 09a07Wd.wav (duration: 2.32s, parts: 2, part_duration: 1.16s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a07Wd_1.wav (duration: 1.16s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a07Wd_2.wav (duration: 1.16s)
#
# Processing: 10a07La.wav (duration: 1.99s, parts: 1, part_duration: 1.99s)
#   Skipping (duration < 2 seconds)
#
# Processing: 03b02Na.wav (duration: 2.95s, parts: 2, part_duration: 1.47s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Na_1.wav (duration: 1.47s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Na_2.wav (duration: 1.47s)
#
# Processing: 09a02Ea.wav (duration: 2.43s, parts: 2, part_duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a02Ea_1.wav (duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a02Ea_2.wav (duration: 1.22s)
#
# Processing: 14b03Ed.wav (duration: 5.05s, parts: 3, part_duration: 1.68s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b03Ed_1.wav (duration: 1.68s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b03Ed_2.wav (duration: 1.68s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b03Ed_3.wav (duration: 1.68s)
#
# Processing: 12b10Ld.wav (duration: 3.02s, parts: 2, part_duration: 1.51s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b10Ld_1.wav (duration: 1.51s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b10Ld_2.wav (duration: 1.51s)
#
# Processing: 09a05Wb.wav (duration: 3.40s, parts: 2, part_duration: 1.70s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a05Wb_1.wav (duration: 1.70s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a05Wb_2.wav (duration: 1.70s)
#
# Processing: 16b01Aa.wav (duration: 2.08s, parts: 2, part_duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Aa_1.wav (duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Aa_2.wav (duration: 1.04s)
#
# Processing: 11a02Fb.wav (duration: 1.79s, parts: 1, part_duration: 1.79s)
#   Skipping (duration < 2 seconds)
#
# Processing: 12b10Ac.wav (duration: 2.03s, parts: 2, part_duration: 1.02s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b10Ac_1.wav (duration: 1.02s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b10Ac_2.wav (duration: 1.02s)
#
# Processing: 15b02Wa.wav (duration: 2.77s, parts: 2, part_duration: 1.38s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b02Wa_1.wav (duration: 1.38s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b02Wa_2.wav (duration: 1.38s)
#
# Processing: 14b09Fc.wav (duration: 2.53s, parts: 2, part_duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b09Fc_1.wav (duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b09Fc_2.wav (duration: 1.26s)
#
# Processing: 09b02Wd.wav (duration: 2.62s, parts: 2, part_duration: 1.31s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b02Wd_1.wav (duration: 1.31s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b02Wd_2.wav (duration: 1.31s)
#
# Processing: 10a04Fd.wav (duration: 1.54s, parts: 1, part_duration: 1.54s)
#   Skipping (duration < 2 seconds)
#
# Processing: 10b02La.wav (duration: 2.69s, parts: 2, part_duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b02La_1.wav (duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b02La_2.wav (duration: 1.35s)
#
# Processing: 03a05Wa.wav (duration: 3.44s, parts: 2, part_duration: 1.72s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a05Wa_1.wav (duration: 1.72s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a05Wa_2.wav (duration: 1.72s)
#
# Processing: 11a04Fd.wav (duration: 1.89s, parts: 1, part_duration: 1.89s)
#   Skipping (duration < 2 seconds)
#
# Processing: 14a01Na.wav (duration: 1.62s, parts: 1, part_duration: 1.62s)
#   Skipping (duration < 2 seconds)
#
# Processing: 08b02Wd.wav (duration: 3.58s, parts: 2, part_duration: 1.79s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b02Wd_1.wav (duration: 1.79s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b02Wd_2.wav (duration: 1.79s)
#
# Processing: 12b02Ea.wav (duration: 5.57s, parts: 3, part_duration: 1.86s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Ea_1.wav (duration: 1.86s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Ea_2.wav (duration: 1.86s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Ea_3.wav (duration: 1.86s)
#
# Processing: 13b09Ab.wav (duration: 2.71s, parts: 2, part_duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b09Ab_1.wav (duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b09Ab_2.wav (duration: 1.36s)
#
# Processing: 13a01Ec.wav (duration: 2.33s, parts: 2, part_duration: 1.16s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a01Ec_1.wav (duration: 1.16s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a01Ec_2.wav (duration: 1.16s)
#
# Processing: 03a07Wc.wav (duration: 2.09s, parts: 2, part_duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a07Wc_1.wav (duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a07Wc_2.wav (duration: 1.04s)
#
# Processing: 14a01Wc.wav (duration: 1.97s, parts: 1, part_duration: 1.97s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13a04Wc.wav (duration: 2.00s, parts: 1, part_duration: 2.00s)
#   Skipping (duration < 2 seconds)
#
# Processing: 12a04Wc.wav (duration: 1.58s, parts: 1, part_duration: 1.58s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16a04Lc.wav (duration: 2.65s, parts: 2, part_duration: 1.33s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a04Lc_1.wav (duration: 1.33s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a04Lc_2.wav (duration: 1.33s)
#
# Processing: 12b09Ac.wav (duration: 2.47s, parts: 2, part_duration: 1.24s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b09Ac_1.wav (duration: 1.24s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b09Ac_2.wav (duration: 1.24s)
#
# Processing: 16a07Fb.wav (duration: 2.43s, parts: 2, part_duration: 1.21s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a07Fb_1.wav (duration: 1.21s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a07Fb_2.wav (duration: 1.21s)
#
# Processing: 10a05Aa.wav (duration: 2.60s, parts: 2, part_duration: 1.30s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10a05Aa_1.wav (duration: 1.30s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10a05Aa_2.wav (duration: 1.30s)
#
# Processing: 16a02Tc.wav (duration: 2.19s, parts: 2, part_duration: 1.10s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a02Tc_1.wav (duration: 1.10s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a02Tc_2.wav (duration: 1.10s)
#
# Processing: 09a05Wc.wav (duration: 3.18s, parts: 2, part_duration: 1.59s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a05Wc_1.wav (duration: 1.59s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a05Wc_2.wav (duration: 1.59s)
#
# Processing: 11b03Fc.wav (duration: 3.83s, parts: 2, part_duration: 1.91s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b03Fc_1.wav (duration: 1.91s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b03Fc_2.wav (duration: 1.91s)
#
# Processing: 11a07Ac.wav (duration: 1.90s, parts: 1, part_duration: 1.90s)
#   Skipping (duration < 2 seconds)
#
# Processing: 10b01Fa.wav (duration: 2.43s, parts: 2, part_duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b01Fa_1.wav (duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b01Fa_2.wav (duration: 1.22s)
#
# Processing: 11a07Ld.wav (duration: 1.80s, parts: 1, part_duration: 1.80s)
#   Skipping (duration < 2 seconds)
#
# Processing: 10a05Tb.wav (duration: 3.33s, parts: 2, part_duration: 1.67s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10a05Tb_1.wav (duration: 1.67s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10a05Tb_2.wav (duration: 1.67s)
#
# Processing: 11b01Fc.wav (duration: 2.55s, parts: 2, part_duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b01Fc_1.wav (duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b01Fc_2.wav (duration: 1.28s)
#
# Processing: 08a07Wc.wav (duration: 2.22s, parts: 2, part_duration: 1.11s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a07Wc_1.wav (duration: 1.11s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a07Wc_2.wav (duration: 1.11s)
#
# Processing: 08b10Fd.wav (duration: 2.46s, parts: 2, part_duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b10Fd_1.wav (duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b10Fd_2.wav (duration: 1.23s)
#
# Processing: 09a02Eb.wav (duration: 1.52s, parts: 1, part_duration: 1.52s)
#   Skipping (duration < 2 seconds)
#
# Processing: 10a07Aa.wav (duration: 1.60s, parts: 1, part_duration: 1.60s)
#   Skipping (duration < 2 seconds)
#
# Processing: 10a05Ld.wav (duration: 3.30s, parts: 2, part_duration: 1.65s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10a05Ld_1.wav (duration: 1.65s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10a05Ld_2.wav (duration: 1.65s)
#
# Processing: 08a07Na.wav (duration: 2.08s, parts: 2, part_duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a07Na_1.wav (duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a07Na_2.wav (duration: 1.04s)
#
# Processing: 09a07Na.wav (duration: 1.84s, parts: 1, part_duration: 1.84s)
#   Skipping (duration < 2 seconds)
#
# Processing: 08a05Wa.wav (duration: 2.93s, parts: 2, part_duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a05Wa_1.wav (duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a05Wa_2.wav (duration: 1.46s)
#
# Processing: 10a02Fa.wav (duration: 1.52s, parts: 1, part_duration: 1.52s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16b03Ta.wav (duration: 5.98s, parts: 3, part_duration: 1.99s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03Ta_1.wav (duration: 1.99s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03Ta_2.wav (duration: 1.99s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03Ta_3.wav (duration: 1.99s)
#
# Processing: 14b02Wb.wav (duration: 2.75s, parts: 2, part_duration: 1.37s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b02Wb_1.wav (duration: 1.37s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b02Wb_2.wav (duration: 1.37s)
#
# Processing: 03a05Wb.wav (duration: 2.96s, parts: 2, part_duration: 1.48s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a05Wb_1.wav (duration: 1.48s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a05Wb_2.wav (duration: 1.48s)
#
# Processing: 15a01Nb.wav (duration: 1.63s, parts: 1, part_duration: 1.63s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16a04La.wav (duration: 2.03s, parts: 2, part_duration: 1.01s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a04La_1.wav (duration: 1.01s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a04La_2.wav (duration: 1.01s)
#
# Processing: 16b02Fd.wav (duration: 3.53s, parts: 2, part_duration: 1.77s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b02Fd_1.wav (duration: 1.77s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b02Fd_2.wav (duration: 1.77s)
#
# Processing: 11b02Td.wav (duration: 3.60s, parts: 2, part_duration: 1.80s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Td_1.wav (duration: 1.80s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Td_2.wav (duration: 1.80s)
#
# Processing: 14a01Wa.wav (duration: 1.64s, parts: 1, part_duration: 1.64s)
#   Skipping (duration < 2 seconds)
#
# Processing: 15a01Wa.wav (duration: 1.83s, parts: 1, part_duration: 1.83s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13a01Ea.wav (duration: 1.83s, parts: 1, part_duration: 1.83s)
#   Skipping (duration < 2 seconds)
#
# Processing: 14b02Na.wav (duration: 2.90s, parts: 2, part_duration: 1.45s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b02Na_1.wav (duration: 1.45s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b02Na_2.wav (duration: 1.45s)
#
# Processing: 08b09Fd.wav (duration: 2.77s, parts: 2, part_duration: 1.38s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b09Fd_1.wav (duration: 1.38s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b09Fd_2.wav (duration: 1.38s)
#
# Processing: 03a07Nc.wav (duration: 1.79s, parts: 1, part_duration: 1.79s)
#   Skipping (duration < 2 seconds)
#
# Processing: 15b09Fa.wav (duration: 2.45s, parts: 2, part_duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b09Fa_1.wav (duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b09Fa_2.wav (duration: 1.23s)
#
# Processing: 15b02Wc.wav (duration: 2.62s, parts: 2, part_duration: 1.31s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b02Wc_1.wav (duration: 1.31s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b02Wc_2.wav (duration: 1.31s)
#
# Processing: 16a07Fa.wav (duration: 2.37s, parts: 2, part_duration: 1.19s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a07Fa_1.wav (duration: 1.19s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a07Fa_2.wav (duration: 1.19s)
#
# Processing: 11a07Ta.wav (duration: 2.17s, parts: 2, part_duration: 1.08s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a07Ta_1.wav (duration: 1.08s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a07Ta_2.wav (duration: 1.08s)
#
# Processing: 10a07Ta.wav (duration: 1.96s, parts: 1, part_duration: 1.96s)
#   Skipping (duration < 2 seconds)
#
# Processing: 09b01Ea.wav (duration: 3.73s, parts: 2, part_duration: 1.87s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b01Ea_1.wav (duration: 1.87s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b01Ea_2.wav (duration: 1.87s)
#
# Processing: 16b01Tb.wav (duration: 4.38s, parts: 3, part_duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Tb_1.wav (duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Tb_2.wav (duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Tb_3.wav (duration: 1.46s)
#
# Processing: 16a05Fc.wav (duration: 3.61s, parts: 2, part_duration: 1.81s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a05Fc_1.wav (duration: 1.81s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a05Fc_2.wav (duration: 1.81s)
#
# Processing: 09a05Nb.wav (duration: 3.08s, parts: 2, part_duration: 1.54s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a05Nb_1.wav (duration: 1.54s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a05Nb_2.wav (duration: 1.54s)
#
# Processing: 09a07Wb.wav (duration: 1.99s, parts: 1, part_duration: 1.99s)
#   Skipping (duration < 2 seconds)
#
# Processing: 08a05Nb.wav (duration: 3.25s, parts: 2, part_duration: 1.63s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a05Nb_1.wav (duration: 1.63s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a05Nb_2.wav (duration: 1.63s)
#
# Processing: 10b01Aa.wav (duration: 2.09s, parts: 2, part_duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b01Aa_1.wav (duration: 1.04s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b01Aa_2.wav (duration: 1.04s)
#
# Processing: 08b10La.wav (duration: 2.80s, parts: 2, part_duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b10La_1.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b10La_2.wav (duration: 1.40s)
#
# Processing: 15b10Ac.wav (duration: 2.02s, parts: 2, part_duration: 1.01s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b10Ac_1.wav (duration: 1.01s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b10Ac_2.wav (duration: 1.01s)
#
# Processing: 10b03Tb.wav (duration: 3.76s, parts: 2, part_duration: 1.88s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b03Tb_1.wav (duration: 1.88s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b03Tb_2.wav (duration: 1.88s)
#
# Processing: 11a02Ld.wav (duration: 1.61s, parts: 1, part_duration: 1.61s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13b03Ed.wav (duration: 4.52s, parts: 3, part_duration: 1.51s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Ed_1.wav (duration: 1.51s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Ed_2.wav (duration: 1.51s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Ed_3.wav (duration: 1.51s)
#
# Processing: 08b01Na.wav (duration: 2.35s, parts: 2, part_duration: 1.18s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b01Na_1.wav (duration: 1.18s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b01Na_2.wav (duration: 1.18s)
#
# Processing: 15a02Wd.wav (duration: 1.82s, parts: 1, part_duration: 1.82s)
#   Skipping (duration < 2 seconds)
#
# Processing: 09b01Na.wav (duration: 2.47s, parts: 2, part_duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b01Na_1.wav (duration: 1.23s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b01Na_2.wav (duration: 1.23s)
#
# Processing: 03b01Nb.wav (duration: 2.39s, parts: 2, part_duration: 1.19s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b01Nb_1.wav (duration: 1.19s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b01Nb_2.wav (duration: 1.19s)
#
# Processing: 12a01Wc.wav (duration: 2.36s, parts: 2, part_duration: 1.18s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12a01Wc_1.wav (duration: 1.18s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12a01Wc_2.wav (duration: 1.18s)
#
# Processing: 15a04Wb.wav (duration: 1.81s, parts: 1, part_duration: 1.81s)
#   Skipping (duration < 2 seconds)
#
# Processing: 03a02Wb.wav (duration: 2.12s, parts: 2, part_duration: 1.06s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a02Wb_1.wav (duration: 1.06s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a02Wb_2.wav (duration: 1.06s)
#
# Processing: 14a04Wb.wav (duration: 1.74s, parts: 1, part_duration: 1.74s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13b02Wa.wav (duration: 2.41s, parts: 2, part_duration: 1.21s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b02Wa_1.wav (duration: 1.21s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b02Wa_2.wav (duration: 1.21s)
#
# Processing: 12b02Wa.wav (duration: 2.78s, parts: 2, part_duration: 1.39s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Wa_1.wav (duration: 1.39s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Wa_2.wav (duration: 1.39s)
#
# Processing: 13b09Fc.wav (duration: 2.96s, parts: 2, part_duration: 1.48s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b09Fc_1.wav (duration: 1.48s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b09Fc_2.wav (duration: 1.48s)
#
# Processing: 03b01Wa.wav (duration: 2.18s, parts: 2, part_duration: 1.09s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b01Wa_1.wav (duration: 1.09s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b01Wa_2.wav (duration: 1.09s)
#
# Processing: 13b09Fb.wav (duration: 2.87s, parts: 2, part_duration: 1.44s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b09Fb_1.wav (duration: 1.44s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b09Fb_2.wav (duration: 1.44s)
#
# Processing: 14a04Wc.wav (duration: 2.51s, parts: 2, part_duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a04Wc_1.wav (duration: 1.25s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a04Wc_2.wav (duration: 1.26s)
#
# Processing: 03a02Wc.wav (duration: 1.50s, parts: 1, part_duration: 1.50s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13a01Wb.wav (duration: 2.36s, parts: 2, part_duration: 1.18s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a01Wb_1.wav (duration: 1.18s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a01Wb_2.wav (duration: 1.18s)
#
# Processing: 03b03Wc.wav (duration: 3.85s, parts: 2, part_duration: 1.92s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b03Wc_1.wav (duration: 1.92s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b03Wc_2.wav (duration: 1.92s)
#
# Processing: 16a01Lb.wav (duration: 2.03s, parts: 2, part_duration: 1.02s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a01Lb_1.wav (duration: 1.02s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a01Lb_2.wav (duration: 1.02s)
#
# Processing: 14b09Ac.wav (duration: 2.29s, parts: 2, part_duration: 1.14s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b09Ac_1.wav (duration: 1.14s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b09Ac_2.wav (duration: 1.14s)
#
# Processing: 13b02Nb.wav (duration: 2.79s, parts: 2, part_duration: 1.39s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b02Nb_1.wav (duration: 1.39s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b02Nb_2.wav (duration: 1.39s)
#
# Processing: 15b09Ac.wav (duration: 2.42s, parts: 2, part_duration: 1.21s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b09Ac_1.wav (duration: 1.21s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b09Ac_2.wav (duration: 1.21s)
#
# Processing: 10a02Ab.wav (duration: 1.61s, parts: 1, part_duration: 1.61s)
#   Skipping (duration < 2 seconds)
#
# Processing: 12a05Nd.wav (duration: 3.19s, parts: 2, part_duration: 1.59s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12a05Nd_1.wav (duration: 1.59s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12a05Nd_2.wav (duration: 1.59s)
#
# Processing: 14b10Tc.wav (duration: 3.41s, parts: 2, part_duration: 1.71s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b10Tc_1.wav (duration: 1.71s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b10Tc_2.wav (duration: 1.71s)
#
# Processing: 16b01Fa.wav (duration: 2.65s, parts: 2, part_duration: 1.32s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Fa_1.wav (duration: 1.32s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Fa_2.wav (duration: 1.32s)
#
# Processing: 09b03Nb.wav (duration: 3.82s, parts: 2, part_duration: 1.91s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Nb_1.wav (duration: 1.91s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Nb_2.wav (duration: 1.91s)
#
# Processing: 08b03Nb.wav (duration: 3.72s, parts: 2, part_duration: 1.86s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b03Nb_1.wav (duration: 1.86s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b03Nb_2.wav (duration: 1.86s)
#
# Processing: 09b01Wb.wav (duration: 2.16s, parts: 2, part_duration: 1.08s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b01Wb_1.wav (duration: 1.08s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b01Wb_2.wav (duration: 1.08s)
#
# Processing: 11a02Tc.wav (duration: 2.06s, parts: 2, part_duration: 1.03s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a02Tc_1.wav (duration: 1.03s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a02Tc_2.wav (duration: 1.03s)
#
# Processing: 16b03Fa.wav (duration: 3.87s, parts: 2, part_duration: 1.93s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03Fa_1.wav (duration: 1.93s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b03Fa_2.wav (duration: 1.93s)
#
# Processing: 11b01Ab.wav (duration: 2.02s, parts: 2, part_duration: 1.01s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b01Ab_1.wav (duration: 1.01s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b01Ab_2.wav (duration: 1.01s)
#
# Processing: 16a05Tb.wav (duration: 6.79s, parts: 4, part_duration: 1.70s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a05Tb_1.wav (duration: 1.70s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a05Tb_2.wav (duration: 1.70s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a05Tb_3.wav (duration: 1.70s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a05Tb_4.wav (duration: 1.70s)
#
# Processing: 09a02Wb.wav (duration: 1.66s, parts: 1, part_duration: 1.66s)
#   Skipping (duration < 2 seconds)
#
# Processing: 11a05Fb.wav (duration: 3.54s, parts: 2, part_duration: 1.77s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Fb_1.wav (duration: 1.77s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Fb_2.wav (duration: 1.77s)
#
# Processing: 09b03Wb.wav (duration: 3.70s, parts: 2, part_duration: 1.85s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Wb_1.wav (duration: 1.85s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Wb_2.wav (duration: 1.85s)
#
# Processing: 13b10Fa.wav (duration: 2.16s, parts: 2, part_duration: 1.08s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b10Fa_1.wav (duration: 1.08s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b10Fa_2.wav (duration: 1.08s)
#
# Processing: 08b09Lc.wav (duration: 3.89s, parts: 2, part_duration: 1.95s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b09Lc_1.wav (duration: 1.95s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b09Lc_2.wav (duration: 1.95s)
#
# Processing: 11b02Fd.wav (duration: 3.11s, parts: 2, part_duration: 1.56s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Fd_1.wav (duration: 1.56s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Fd_2.wav (duration: 1.56s)
#
# Processing: 15a04Wa.wav (duration: 1.95s, parts: 1, part_duration: 1.95s)
#   Skipping (duration < 2 seconds)
#
# Processing: 12b02Wb.wav (duration: 2.80s, parts: 2, part_duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Wb_1.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Wb_2.wav (duration: 1.40s)
#
# Processing: 03b01Wc.wav (duration: 2.93s, parts: 2, part_duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b01Wc_1.wav (duration: 1.46s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b01Wc_2.wav (duration: 1.46s)
#
# Processing: 16b02Lb.wav (duration: 3.40s, parts: 2, part_duration: 1.70s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b02Lb_1.wav (duration: 1.70s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b02Lb_2.wav (duration: 1.70s)
#
# Processing: 13a01Nb.wav (duration: 1.52s, parts: 1, part_duration: 1.52s)
#   Skipping (duration < 2 seconds)
#
# Processing: 12a01Nb.wav (duration: 1.72s, parts: 1, part_duration: 1.72s)
#   Skipping (duration < 2 seconds)
#
# Processing: 15a04Nc.wav (duration: 1.70s, parts: 1, part_duration: 1.70s)
#   Skipping (duration < 2 seconds)
#
# Processing: 03a02Nc.wav (duration: 1.44s, parts: 1, part_duration: 1.44s)
#   Skipping (duration < 2 seconds)
#
# Processing: 15b09Ta.wav (duration: 4.02s, parts: 3, part_duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b09Ta_1.wav (duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b09Ta_2.wav (duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b09Ta_3.wav (duration: 1.34s)
#
# Processing: 03b03Nb.wav (duration: 3.64s, parts: 2, part_duration: 1.82s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b03Nb_1.wav (duration: 1.82s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b03Nb_2.wav (duration: 1.82s)
#
# Processing: 15a01Ea.wav (duration: 2.55s, parts: 2, part_duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15a01Ea_1.wav (duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15a01Ea_2.wav (duration: 1.28s)
#
# Processing: 14a01Ea.wav (duration: 3.14s, parts: 2, part_duration: 1.57s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a01Ea_1.wav (duration: 1.57s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a01Ea_2.wav (duration: 1.57s)
#
# Processing: 12b02Na.wav (duration: 2.98s, parts: 2, part_duration: 1.49s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Na_1.wav (duration: 1.49s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b02Na_2.wav (duration: 1.49s)
#
# Processing: 09a07Eb.wav (duration: 3.35s, parts: 2, part_duration: 1.67s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a07Eb_1.wav (duration: 1.67s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a07Eb_2.wav (duration: 1.67s)
#
# Processing: 11a05Fc.wav (duration: 3.93s, parts: 2, part_duration: 1.96s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Fc_1.wav (duration: 1.96s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Fc_2.wav (duration: 1.96s)
#
# Processing: 03b09La.wav (duration: 3.11s, parts: 2, part_duration: 1.56s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b09La_1.wav (duration: 1.56s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b09La_2.wav (duration: 1.56s)
#
# Processing: 08a02Wc.wav (duration: 1.87s, parts: 1, part_duration: 1.87s)
#   Skipping (duration < 2 seconds)
#
# Processing: 08b01Wa.wav (duration: 3.31s, parts: 2, part_duration: 1.65s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b01Wa_1.wav (duration: 1.65s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b01Wa_2.wav (duration: 1.65s)
#
# Processing: 16a05Ab.wav (duration: 2.90s, parts: 2, part_duration: 1.45s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a05Ab_1.wav (duration: 1.45s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a05Ab_2.wav (duration: 1.45s)
#
# ...
#   Skipping (duration < 2 seconds)
#
# Processing: 16b01Wa.wav (duration: 2.61s, parts: 2, part_duration: 1.30s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Wa_1.wav (duration: 1.30s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b01Wa_2.wav (duration: 1.30s)
#
# Processing: 08a07Ta.wav (duration: 3.46s, parts: 2, part_duration: 1.73s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a07Ta_1.wav (duration: 1.73s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a07Ta_2.wav (duration: 1.73s)
#
# Processing: 13b10Wc.wav (duration: 2.68s, parts: 2, part_duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b10Wc_1.wav (duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b10Wc_2.wav (duration: 1.34s)
#
# Processing: 10b01Ea.wav (duration: 2.39s, parts: 2, part_duration: 1.20s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b01Ea_1.wav (duration: 1.20s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b01Ea_2.wav (duration: 1.20s)
#
# Processing: 09a07Ta.wav (duration: 1.99s, parts: 1, part_duration: 1.99s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13a07Fd.wav (duration: 2.01s, parts: 2, part_duration: 1.01s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a07Fd_1.wav (duration: 1.01s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a07Fd_2.wav (duration: 1.01s)
#
# Processing: 09b03Fd.wav (duration: 3.31s, parts: 2, part_duration: 1.66s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Fd_1.wav (duration: 1.66s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b03Fd_2.wav (duration: 1.66s)
#
# Processing: 14a05Ac.wav (duration: 4.10s, parts: 3, part_duration: 1.37s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Ac_1.wav (duration: 1.37s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Ac_2.wav (duration: 1.37s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Ac_3.wav (duration: 1.37s)
#
# Processing: 11a05Wd.wav (duration: 4.04s, parts: 3, part_duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Wd_1.wav (duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Wd_2.wav (duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11a05Wd_3.wav (duration: 1.35s)
#
# Processing: 12b03Ta.wav (duration: 6.00s, parts: 3, part_duration: 2.00s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b03Ta_1.wav (duration: 2.00s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b03Ta_2.wav (duration: 2.00s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b03Ta_3.wav (duration: 2.00s)
#
# Processing: 13b01Ab.wav (duration: 2.22s, parts: 2, part_duration: 1.11s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b01Ab_1.wav (duration: 1.11s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b01Ab_2.wav (duration: 1.11s)
#
# Processing: 13a02Ta.wav (duration: 1.86s, parts: 1, part_duration: 1.86s)
#   Skipping (duration < 2 seconds)
#
# Processing: 03b02Tb.wav (duration: 5.13s, parts: 3, part_duration: 1.71s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Tb_1.wav (duration: 1.71s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Tb_2.wav (duration: 1.71s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Tb_3.wav (duration: 1.71s)
#
# Processing: 14a07Aa.wav (duration: 2.06s, parts: 2, part_duration: 1.03s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Aa_1.wav (duration: 1.03s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Aa_2.wav (duration: 1.03s)
#
# Processing: 14b01Fc.wav (duration: 2.54s, parts: 2, part_duration: 1.27s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b01Fc_1.wav (duration: 1.27s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b01Fc_2.wav (duration: 1.27s)
#
# Processing: 08a01Ab.wav (duration: 1.85s, parts: 1, part_duration: 1.85s)
#   Skipping (duration < 2 seconds)
#
# Processing: 10a01Nb.wav (duration: 1.81s, parts: 1, part_duration: 1.81s)
#   Skipping (duration < 2 seconds)
#
# Processing: 15b02Lb.wav (duration: 2.96s, parts: 2, part_duration: 1.48s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b02Lb_1.wav (duration: 1.48s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S15_15b02Lb_2.wav (duration: 1.48s)
#
# Processing: 16a04Nc.wav (duration: 1.83s, parts: 1, part_duration: 1.83s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16b02Eb.wav (duration: 4.19s, parts: 3, part_duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b02Eb_1.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b02Eb_2.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b02Eb_3.wav (duration: 1.40s)
#
# Processing: 11b02Wb.wav (duration: 3.25s, parts: 2, part_duration: 1.62s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Wb_1.wav (duration: 1.62s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Wb_2.wav (duration: 1.62s)
#
# Processing: 10b02Wb.wav (duration: 2.87s, parts: 2, part_duration: 1.43s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b02Wb_1.wav (duration: 1.43s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b02Wb_2.wav (duration: 1.43s)
#
# Processing: 03a07La.wav (duration: 2.40s, parts: 2, part_duration: 1.20s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a07La_1.wav (duration: 1.20s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03a07La_2.wav (duration: 1.20s)
#
# Processing: 11b02Na.wav (duration: 2.70s, parts: 2, part_duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Na_1.wav (duration: 1.35s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S11_11b02Na_2.wav (duration: 1.35s)
#
# Processing: 15a01La.wav (duration: 1.56s, parts: 1, part_duration: 1.56s)
#   Skipping (duration < 2 seconds)
#
# Processing: 10b02Na.wav (duration: 2.72s, parts: 2, part_duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b02Na_1.wav (duration: 1.36s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b02Na_2.wav (duration: 1.36s)
#
# Processing: 10a01Wa.wav (duration: 2.17s, parts: 2, part_duration: 1.09s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10a01Wa_1.wav (duration: 1.09s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10a01Wa_2.wav (duration: 1.09s)
#
# Processing: 14a05Tc.wav (duration: 5.03s, parts: 3, part_duration: 1.68s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Tc_1.wav (duration: 1.68s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Tc_2.wav (duration: 1.68s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Tc_3.wav (duration: 1.68s)
#
# Processing: 08a02Fe.wav (duration: 1.62s, parts: 1, part_duration: 1.62s)
#   Skipping (duration < 2 seconds)
#
# Processing: 13b01Ld.wav (duration: 2.67s, parts: 2, part_duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b01Ld_1.wav (duration: 1.34s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b01Ld_2.wav (duration: 1.34s)
#
# Processing: 08b03Fe.wav (duration: 3.62s, parts: 2, part_duration: 1.81s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b03Fe_1.wav (duration: 1.81s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b03Fe_2.wav (duration: 1.81s)
#
# Processing: 16b10Aa.wav (duration: 2.58s, parts: 2, part_duration: 1.29s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b10Aa_1.wav (duration: 1.29s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b10Aa_2.wav (duration: 1.29s)
#
# Processing: 14a07Tc.wav (duration: 3.26s, parts: 2, part_duration: 1.63s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Tc_1.wav (duration: 1.63s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Tc_2.wav (duration: 1.63s)
#
# Processing: 08b01Fe.wav (duration: 2.52s, parts: 2, part_duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b01Fe_1.wav (duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b01Fe_2.wav (duration: 1.26s)
#
# Processing: 12a02Ac.wav (duration: 1.23s, parts: 1, part_duration: 1.23s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16b10Tb.wav (duration: 3.50s, parts: 2, part_duration: 1.75s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b10Tb_1.wav (duration: 1.75s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b10Tb_2.wav (duration: 1.75s)
#
# Processing: 14a05Ta.wav (duration: 3.74s, parts: 2, part_duration: 1.87s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Ta_1.wav (duration: 1.87s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Ta_2.wav (duration: 1.87s)
#
# Processing: 13b03Ac.wav (duration: 3.31s, parts: 2, part_duration: 1.65s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Ac_1.wav (duration: 1.65s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13b03Ac_2.wav (duration: 1.65s)
#
# Processing: 11a01Wc.wav (duration: 1.92s, parts: 1, part_duration: 1.92s)
#   Skipping (duration < 2 seconds)
#
# Processing: 16a04Wb.wav (duration: 2.56s, parts: 2, part_duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a04Wb_1.wav (duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a04Wb_2.wav (duration: 1.28s)
#
# Processing: 16b09Ab.wav (duration: 2.05s, parts: 2, part_duration: 1.03s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b09Ab_1.wav (duration: 1.03s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16b09Ab_2.wav (duration: 1.03s)
#
# Processing: 09b02Tb.wav (duration: 3.65s, parts: 2, part_duration: 1.83s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b02Tb_1.wav (duration: 1.83s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b02Tb_2.wav (duration: 1.83s)
#
# Processing: 16a01Ec.wav (duration: 2.43s, parts: 2, part_duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a01Ec_1.wav (duration: 1.22s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S16_16a01Ec_2.wav (duration: 1.22s)
#
# Processing: 13a04Lb.wav (duration: 2.25s, parts: 2, part_duration: 1.12s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a04Lb_1.wav (duration: 1.12s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S13_13a04Lb_2.wav (duration: 1.12s)
#
# Processing: 15a04Fd.wav (duration: 1.79s, parts: 1, part_duration: 1.79s)
#   Skipping (duration < 2 seconds)
#
# Processing: 03b10Ec.wav (duration: 3.20s, parts: 2, part_duration: 1.60s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b10Ec_1.wav (duration: 1.60s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b10Ec_2.wav (duration: 1.60s)
#
# Processing: 13a01Fd.wav (duration: 1.88s, parts: 1, part_duration: 1.88s)
#   Skipping (duration < 2 seconds)
#
# Processing: 09b09Ea.wav (duration: 3.79s, parts: 2, part_duration: 1.90s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b09Ea_1.wav (duration: 1.90s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09b09Ea_2.wav (duration: 1.90s)
#
# Processing: 08b02Tc.wav (duration: 7.68s, parts: 4, part_duration: 1.92s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b02Tc_1.wav (duration: 1.92s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b02Tc_2.wav (duration: 1.92s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b02Tc_3.wav (duration: 1.92s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b02Tc_4.wav (duration: 1.92s)
#
# Processing: 16a04Wc.wav (duration: 1.94s, parts: 1, part_duration: 1.94s)
#   Skipping (duration < 2 seconds)
#
# Processing: 14b01Fa.wav (duration: 2.56s, parts: 2, part_duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b01Fa_1.wav (duration: 1.28s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14b01Fa_2.wav (duration: 1.28s)
#
# Processing: 14a07Ld.wav (duration: 2.29s, parts: 2, part_duration: 1.15s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Ld_1.wav (duration: 1.15s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a07Ld_2.wav (duration: 1.15s)
#
# Processing: 15a07Ld.wav (duration: 1.80s, parts: 1, part_duration: 1.80s)
#   Skipping (duration < 2 seconds)
#
# Processing: 12b01Ta.wav (duration: 4.00s, parts: 2, part_duration: 2.00s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b01Ta_1.wav (duration: 2.00s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S12_12b01Ta_2.wav (duration: 2.00s)
#
# Processing: 10b10Fc.wav (duration: 2.21s, parts: 2, part_duration: 1.11s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b10Fc_1.wav (duration: 1.11s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S10_10b10Fc_2.wav (duration: 1.11s)
#
# Processing: 15a07Ac.wav (duration: 1.81s, parts: 1, part_duration: 1.81s)
#   Skipping (duration < 2 seconds)
#
# Processing: 08a07La.wav (duration: 2.52s, parts: 2, part_duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a07La_1.wav (duration: 1.26s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a07La_2.wav (duration: 1.26s)
#
# Processing: 08b01Fd.wav (duration: 2.48s, parts: 2, part_duration: 1.24s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b01Fd_1.wav (duration: 1.24s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08b01Fd_2.wav (duration: 1.24s)
#
# Processing: 03b02Aa.wav (duration: 3.08s, parts: 2, part_duration: 1.54s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Aa_1.wav (duration: 1.54s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S03_03b02Aa_2.wav (duration: 1.54s)
#
# Processing: 09a05Lc.wav (duration: 3.37s, parts: 2, part_duration: 1.68s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a05Lc_1.wav (duration: 1.68s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S09_09a05Lc_2.wav (duration: 1.68s)
#
# Processing: 08a05Lc.wav (duration: 4.19s, parts: 3, part_duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a05Lc_1.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a05Lc_2.wav (duration: 1.40s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S08_08a05Lc_3.wav (duration: 1.40s)
#
# Processing: 14a05Aa.wav (duration: 2.59s, parts: 2, part_duration: 1.29s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Aa_1.wav (duration: 1.29s)
# Created: /Users/adityakumar/Developer/Projects/mini_project/output/S14_14a05Aa_2.wav (duration: 1.29s)

# %% [markdown]
# ## Making CSV table of filename and duration for output

# %%
info_path = "/Users/adityakumar/Developer/Projects/mini_project/info"
output_path = "/Users/adityakumar/Developer/Projects/mini_project/output"

print(create_audio_duration_csv(output_path, info_path))
# Out:
# CSV created at: /Users/adityakumar/Developer/Projects/mini_project/info/audio_durations.csv with 872 files
# /Users/adityakumar/Developer/Projects/mini_project/info/audio_durations.csv

# %% [markdown]
# # Building the CSV label

# %%
import pandas as pd

def parse_filename(filename):
    """
    Parse filename to extract speaker_id, text_code, emotion_code, and version.
    Format: SXX_SSPPPEV_X.wav
    - SXX: Speaker prefix (e.g., S03)
    - SSPPPEV: Original filename
    - X: Part number
    Example: S03_03a05Tc_1.wav
    """
    # Remove .wav extension
    base_name = filename.replace('.wav', '')
    
    # Split by underscore
    parts = base_name.split('_')
    
    # First part is speaker ID (e.g., S03)
    speaker_prefix = parts[0] if parts else ''
    speaker_id = speaker_prefix[1:] if speaker_prefix.startswith('S') else speaker_prefix
    
    # Middle part is the original filename (e.g., 03a05Tc)
    if len(parts) >= 2:
        original_name = parts[1]
    else:
        original_name = base_name
    
    # Parse the original filename
    text_code = original_name[2:5] if len(original_name) > 5 else ''
    emotion_code = original_name[5] if len(original_name) > 5 else ''
    version = original_name[6] if len(original_name) > 6 else ''
    
    return speaker_id, text_code, emotion_code, version

def get_emotion_label(emotion_code):
    """
    Map German emotion code to emotion label.
    """
    emotion_map = {
        'W': 'Anger',      # Wut
        'L': 'Boredom',    # Langeweile
        'E': 'Disgust',    # Ekel
        'A': 'Anxiety',    # Angst
        'F': 'Happiness',  # Freude
        'T': 'Sadness',    # Traurigkeit
        'N': 'Neutral'     # Neutral
    }
    return emotion_map.get(emotion_code, 'Unknown')

def get_emotion_number(emotion_label):
    """
    Map emotion label to numeral.
    """
    emotion_number_map = {
        'Happiness': 0,
        'Neutral': 1,
        'Anger': 2,
        'Anxiety': 3,
        'Boredom': 4,
        'Disgust': 5,
        'Sadness': 6
    }
    return emotion_number_map.get(emotion_label, -1)

def create_label_csv(output_folder, info_folder):
    """
    Create a CSV file with labels for all audio files.
    Columns: ID, duration, wav, start, stop, spk_id, label
    """
    # Read the audio_durations.csv file
    durations_csv = os.path.join(info_folder, 'audio_durations.csv')
    df_durations = pd.read_csv(durations_csv)
    
    # List to store all rows
    rows = []
    
    # Process each file
    for idx, row in df_durations.iterrows():
        filename = row['filename']
        duration = row['duration(sec)']
        
        # Parse filename
        speaker_id, text_code, emotion_code, version = parse_filename(filename)
        emotion_label = get_emotion_label(emotion_code)
        emotion_number = get_emotion_number(emotion_label)
        
        # Get part number from filename
        # Format: SXX_filename_part.wav
        parts = filename.replace('.wav', '').split('_')
        if len(parts) >= 3:
            part_num = int(parts[-1])
            base_filename = parts[1]  # Original filename without speaker prefix and part number
        else:
            part_num = 1
            base_filename = parts[1] if len(parts) >= 2 else filename.replace('.wav', '')
        
        original_filename = base_filename + '.wav'
        
        # Calculate start and stop times
        # We need to determine how many parts the original file was split into
        # by checking how many files share the same base name (SXX_filename_)
        same_base_files = df_durations[df_durations['filename'].str.contains(f'_{base_filename}_')]
        total_parts = len(same_base_files)
        
        if total_parts == 0:
            # File wasn't split
            start_time = 0.0
            stop_time = duration
        else:
            # File was split - calculate based on part number
            # Get total duration of all parts
            total_duration = same_base_files['duration(sec)'].sum()
            
            # Calculate cumulative duration up to this part
            parts_before = same_base_files[same_base_files['filename'] < filename]
            start_time = parts_before['duration(sec)'].sum() if len(parts_before) > 0 else 0.0
            stop_time = start_time + duration
        
        # File location
        file_location = os.path.join(output_folder, filename)
        
        # Create row
        rows.append({
            'ID': f'S{speaker_id}--{filename.replace(".wav", "")}',
            'duration': duration,
            'wav': file_location,
            'start': 0,
            'stop': int(duration*16000),
            'spk_id': f'S{speaker_id}',
            'label': emotion_number
        })
    
    # Create DataFrame
    df_labels = pd.DataFrame(rows)
    
    # Save to CSV
    output_csv = os.path.join(info_folder, 'audio_labels.csv')
    df_labels.to_csv(output_csv, index=False)
    
    print(f"Label CSV created at: {output_csv}")
    print(f"Total entries: {len(df_labels)}")
    print(f"\nFirst few entries:")
    print(df_labels.head(10))
    
    return output_csv

# Create the label CSV
output_folder = "/Users/adityakumar/Developer/Projects/mini_project/output"
info_folder = "/Users/adityakumar/Developer/Projects/mini_project/info"
create_label_csv(output_folder, info_folder)
# Out:
# Label CSV created at: /Users/adityakumar/Developer/Projects/mini_project/info/audio_labels.csv
# Total entries: 872
#
# First few entries:
#                    ID  duration  \
# 0  S14--S14_14b01Fc_1      1.27
# 1  S10--S10_10b02Aa_2      1.23
# 2  S12--S12_12b10Ld_2      1.51
# 3  S13--S13_13b03Td_1      1.66
# 4  S16--S16_16a04Ea_2      1.32
# 5  S11--S11_11b02Ab_2      1.24
# 6  S14--S14_14b02Fb_1      1.42
# 7  S08--S08_08a07Wc_1      1.11
# 8  S11--S11_11b03Wb_3      1.74
# 9  S15--S15_15b03Nb_2      1.60
#
#                                                  wav  start   stop spk_id  \
# 0  /Users/adityakumar/Developer/Projects/mini_pro...      0  20320    S14
# 1  /Users/adityakumar/Developer/Projects/mini_pro...      0  19680    S10
# 2  /Users/adityakumar/Developer/Projects/mini_pro...      0  24160    S12
# 3  /Users/adityakumar/Developer/Projects/mini_pro...      0  26560    S13
# 4  /Users/adityakumar/Developer/Projects/mini_pro...      0  21120    S16
# 5  /Users/adityakumar/Developer/Projects/mini_pro...      0  19840    S11
# 6  /Users/adityakumar/Developer/Projects/mini_pro...      0  22720    S14
# 7  /Users/adityakumar/Developer/Projects/mini_pro...      0  17760    S08
# 8  /Users/adityakumar/Developer/Projects/mini_pro...      0  27840    S11
# 9  /Users/adityakumar/Developer/Projects/mini_pro...      0  25600    S15
#
#    label
# 0      0
# 1      3
# 2      4
# 3      6
# 4      5
# 5      3
# 6      0
# 7      2
# 8      2
# 9      1
# '/Users/adityakumar/Developer/Projects/mini_project/info/audio_labels.csv'

# %% [markdown]
# ## Mapping the emotion to number
